# %%
def sum_func(first,second): #더하기
  input("Input two numbers".split('.'))
  result=first+second
  print("Inside the function",result)
  print("Outside after call function", result)
  return result

# %%
sum_func(20,10)
# Out:
# ['Input two numbers']20,10
# Inside the function 30
# Outside after call function 30
# 30

# %%
def minus_func(first,second): #빼기
  x=input("Input two numbers".split(','))
  result=first-second
  print("Inside the function",result)
  y=result
  print("Outside after call function", y)
  return result

# %%
minus_func(20,10)
# Out:
# ['Input two numbers']20,10
# Inside the function 10
# Outside after call function 10
# 10

# %%
def mul_func(first,second): #곱하기
  x=input("Input two numbers".split(','))
  result=first*second
  print("Inside the function",result)
  y=result
  print("Outside after call function", y)
  return result

# %%
mul_func(20,10)
# Out:
# ['Input two numbers']20,10
# Inside the function 200
# Outside after call function 200
# 200

# %%
def dev_func(first,second): #나누기
  x=input("Input two numbers".split(','))
  result=first/second
  print("Inside the function",result)
  print("Outside after call function", result)
  return result

# %%
dev_func(20,10)
# Out:
# ['Input two numbers']20,10
# Inside the function 2.0
# Outside after call function 2.0
# 2.0

# %%
dev_func
# Out:
# <function __main__.dev_func>
